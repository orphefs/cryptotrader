# %%
import pandas as pd
import os
import seaborn as sb
import matplotlib.pyplot as plt
DATA_DIR = "/home/orphefs/Documents/Code/autotrader/autotrader/data"

# %%
df = pd.read_pickle(os.path.join(DATA_DIR, "batch_results.pkl"))

# %%
df
# Out:
#     index_performance  net_gains  net_gains_per_day  percentage_gains  \
# 0           -0.037006   0.513036           0.128527          0.476030
# 1            0.003895  -0.000508          -0.000284          0.003387
# 2           -0.059591   0.590578           0.118544          0.530987
# 3            0.003895  -0.000508          -0.000284          0.003387
# 4            0.044632  -0.048000          -0.027429         -0.003368
# 5            0.000702   0.016702           0.003462          0.017404
# 6           -0.035313   0.050602           0.017255          0.015289
# 7            0.000702   0.016702           0.003462          0.017404
# 8           -0.035313   0.050602           0.017255          0.015289
# 9            0.014008  -0.000675          -0.000377          0.013333
# 10           0.044632  -0.048000          -0.027429         -0.003368
# 11          -0.082572   0.095064           0.049509          0.012492
# ...

# %%
sb.boxplot(x="percentage_gains", y="net_gains", data=df)
plt.show()

# %%
sb.scatterplot(x="training_duration_days", y="net_gains_per_day", data=df)
plt.show()
