# %%
import pandas as pd
import os
import seaborn as sb
import matplotlib.pyplot as plt
import numpy as np
DATA_DIR = "/home/orphefs/Documents/Code/autotrader/autotrader/data"

# %%
df = pd.read_pickle(os.path.join(DATA_DIR, "batch_results_binance.pkl"))

# %%
df
# Out:
#     index_performance  net_gains  net_gains_per_day  percentage_gains  \
# 0            0.092443   0.039426           0.019768          0.131869
# 1           -0.009919   0.973558           0.097451          0.963639
# 2           -0.009100   0.972096           0.097311          0.962997
# 3           -0.068485   0.936269           0.078059          0.867784
# 4            0.092443   0.111268           0.055789          0.203711
# 5           -0.003305   0.441179           0.110410          0.437874
# 6            0.014453   0.092241           0.092626          0.106693
# 7            0.014453   0.101637           0.102062          0.116089
# 8           -0.068485   0.960248           0.080058          0.891763
# 9           -0.067469   0.753138           0.107816          0.685669
# 10           0.014453   0.097421           0.097828          0.111873
# 11           0.023247   0.612556           0.068114          0.635803
# ...

# %%
sb.boxplot(x="training_duration_days", y="net_gains_per_day", data=df, color="skyblue")
plt.show()

# %%
print(np.median(df["net_gains_per_day"]))
# Out:
# 0.0943294587423

# %%
sb.scatterplot(x="testing_duration_days", y="net_gains", data=df)
plt.show()
