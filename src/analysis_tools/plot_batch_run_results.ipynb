# %%
import pandas as pd
import os
import seaborn as sb
import matplotlib.pyplot as plt
import numpy as np
DATA_DIR = "/home/orphefs/Documents/Code/autotrader/autotrader/data"

# %%
df = pd.read_pickle(os.path.join(DATA_DIR, "batch_results.pkl"))

# %%
df
# Out:
#      index_performance  net_gains  net_gains_per_day  percentage_gains  \
# 0             0.027006   0.033360           0.024547          0.060365
# 1            -0.012415   0.443732           0.148151          0.431318
# 2            -0.028182   0.027273           0.015823         -0.000909
# 3             0.050590   0.081282           0.013553          0.131872
# 4            -0.025369   0.287341           0.096025          0.261973
# 5             0.029692   1.241012           0.248790          1.270704
# 6             0.055478  -0.024773          -0.012447          0.030705
# 7             0.008734   0.003493           0.000944          0.012227
# 8            -0.077555  -0.061131          -0.029669         -0.138686
# 9             0.056338  -0.026002          -0.008068          0.030336
# 10            0.008790   0.435970           0.087291          0.444760
# 11            0.065313  -0.068716          -0.014709         -0.003403
# ...

# %%
sb.boxplot(x="training_duration_days", y="net_gains_per_day", data=df, color="skyblue")
plt.show()

# %%
print(np.mean(df["net_gains_per_day"]))
# Out:
# 0.05439204800142606

# %%
sb.scatterplot(x="testing_duration_days", y="net_gains_per_day", data=df)
plt.show()
